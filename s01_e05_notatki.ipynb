# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
# %matplotlib inline

# %%
seed = np.random.RandomState(10)
seed2 = np.random.RandomState(11)
age = seed.normal(40,5,25).round(0)
sex = seed.binomial(1,0.5,25)
hap = (seed.beta(20,5,25)*11).round(0)
salary = (seed.gamma(4,50,25)*10).round(-2)
prog = seed.binomial(1,0.5,25)
health = seed2.normal(120,45,25).round(-1)

# %%
dataDict = {
    'Wiek': age,
    'Zarobki': salary,
    'Płeć': sex,
    'Szczęście': hap,
    'Programowanie': prog,
    'Zdrowie': health
}

# %%
myData = pd.DataFrame(data = dataDict)

# %%
myData
# Out:
#     Programowanie  Płeć  Szczęście  Wiek  Zarobki  Zdrowie
# 0               0     1        9.0  47.0   3600.0    200.0
# 1               0     1        8.0  44.0   1800.0    110.0
# 2               0     1        9.0  32.0   1400.0    100.0
# 3               0     0        8.0  40.0   1000.0      0.0
# 4               1     0        8.0  43.0   1500.0    120.0
# 5               0     0        8.0  36.0   2400.0    110.0
# 6               0     0        9.0  41.0   2300.0    100.0
# 7               1     1       10.0  41.0   1600.0    130.0
# 8               0     0       10.0  40.0   1900.0    140.0
# 9               0     1        9.0  39.0   2900.0     70.0
# 10              1     1        8.0  42.0   2300.0     80.0
# 11              0     1        8.0  46.0   2500.0    100.0
# 12              1     0        9.0  35.0   1500.0    150.0
# 13              0     1        9.0  45.0   1200.0    150.0
# 14              1     0        8.0  41.0    600.0     60.0
# ...

# %%
data = pd.read_csv('https://raw.githubusercontent.com/kpswps/py/master/datasets/titanic_train.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#jeśli chcemy jednąś zmienną wyświetlić
data['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
# 5        male
# 6        male
# 7        male
# 8      female
# 9      female
# 10     female
# 11     female
# 12       male
# 13       male
# 14     female
# 15     female
# 16       male
# 17       male
# 18     female
# 19     female
# 20       male
# 21       male
# 22     female
# 23       male
# 24     female
# 25     female
# 26       male
# 27       male
# 28     female
# 29       male
#         ...
# 861      male
# 862    female
# 863    female
# 864      male
# 865    female
# 866    female
# 867      male
# 868      male
# 869      male
# 870      male
# 871    female
# 872      male
# 873      male
# 874    female
# 875    female
# 876      male
# 877      male
# 878      male
# 879    female
# 880    female
# 881      male
# 882    female
# 883      male
# 884      male
# 885    female
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# ...

# %%
#inny sposób
data.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-88cae4a5bf31> in <module>()
# ----> 1 data[0]
#
# ...

# %%
#dopiero tak zadziała, bez sensu
data[0:1]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
data[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
literki = list(map(chr, range(65, 65+25)))
myData.index = literki

# %%
myData
# Out:
#    Programowanie  Płeć  Szczęście  Wiek  Zarobki  Zdrowie
# A              0     1        9.0  47.0   3600.0    200.0
# B              0     1        8.0  44.0   1800.0    110.0
# C              0     1        9.0  32.0   1400.0    100.0
# D              0     0        8.0  40.0   1000.0      0.0
# E              1     0        8.0  43.0   1500.0    120.0
# F              0     0        8.0  36.0   2400.0    110.0
# G              0     0        9.0  41.0   2300.0    100.0
# H              1     1       10.0  41.0   1600.0    130.0
# I              0     0       10.0  40.0   1900.0    140.0
# J              0     1        9.0  39.0   2900.0     70.0
# K              1     1        8.0  42.0   2300.0     80.0
# L              0     1        8.0  46.0   2500.0    100.0
# M              1     0        9.0  35.0   1500.0    150.0
# N              0     1        9.0  45.0   1200.0    150.0
# O              1     0        8.0  41.0    600.0     60.0
# ...

# %%
myData.loc['A']
# Out:
# Programowanie       0.0
# Płeć                1.0
# Szczęście           9.0
# Wiek               47.0
# Zarobki          3600.0
# Zdrowie           200.0
# Name: A, dtype: float64

# %%
myData.loc['A':'F']
# Out:
#    Programowanie  Płeć  Szczęście  Wiek  Zarobki  Zdrowie
# A              0     1        9.0  47.0   3600.0    200.0
# B              0     1        8.0  44.0   1800.0    110.0
# C              0     1        9.0  32.0   1400.0    100.0
# D              0     0        8.0  40.0   1000.0      0.0
# E              1     0        8.0  43.0   1500.0    120.0
# F              0     0        8.0  36.0   2400.0    110.0

# %%
# ooo, wziął wszystkie, razem z F!!!!!

myData.loc[['A', 'C', 'F', 'H']]
# TU MUSI BYĆ DODATKOWY NAWiaS []
# Out:
#    Programowanie  Płeć  Szczęście  Wiek  Zarobki  Zdrowie
# A              0     1        9.0  47.0   3600.0    200.0
# C              0     1        9.0  32.0   1400.0    100.0
# F              0     0        8.0  36.0   2400.0    110.0
# H              1     1       10.0  41.0   1600.0    130.0

# %%
myData.loc['A':'D', 'Płeć':'Wiek']
# wybieramy wiersze od A do D i kolumny od ... do ..
# Out:
#    Płeć  Szczęście  Wiek
# A     1        9.0  47.0
# B     1        8.0  44.0
# C     1        9.0  32.0
# D     0        8.0  40.0

# %%
myData.loc[:, 'Płeć':'Wiek']
# jak wszystkie kolumny, to wpisać   :
# Out:
#    Płeć  Szczęście  Wiek
# A     1        9.0  47.0
# B     1        8.0  44.0
# C     1        9.0  32.0
# D     0        8.0  40.0
# E     0        8.0  43.0
# F     0        8.0  36.0
# G     0        9.0  41.0
# H     1       10.0  41.0
# I     0       10.0  40.0
# J     1        9.0  39.0
# K     1        8.0  42.0
# L     1        8.0  46.0
# M     0        9.0  35.0
# N     1        9.0  45.0
# O     0        8.0  41.0
# P     1        9.0  42.0
# Q     0        9.0  34.0
# R     1        9.0  41.0
# S     0        9.0  47.0
# T     0        7.0  35.0
# U     0        9.0  30.0
# V     0        8.0  31.0
# W     1       10.0  41.0
# X     0        8.0  52.0
# Y     0        7.0  46.0

# %%
data.loc[:10]
# da z 10, bo to nazwa dla niego! w funkcji loc
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# ...

# %%
data.loc[:10, ['Survived', 'Pclass', 'Sex', 'Age']]
# Out:
#     Survived  Pclass     Sex   Age
# 0          0       3    male  22.0
# 1          1       1  female  38.0
# 2          1       3  female  26.0
# 3          1       1  female  35.0
# 4          0       3    male  35.0
# 5          0       3    male   NaN
# 6          0       1    male  54.0
# 7          0       3    male   2.0
# 8          1       3  female  27.0
# 9          1       2  female  14.0
# 10         1       3  female   4.0

# %%
data.iloc[:10,  [1,2,4,6]]
# metoda wybierania po indeksach, a nie nazwach
# Out:
#    Survived  Pclass     Sex  SibSp
# 0         0       3    male      1
# 1         1       1  female      1
# 2         1       3  female      0
# 3         1       1  female      1
# 4         0       3    male      0
# 5         0       3    male      0
# 6         0       1    male      0
# 7         0       3    male      3
# 8         1       3  female      0
# 9         1       2  female      1

# %%
data.iloc[:10, : ]
# : jak chcemy wszystkie
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.iloc[300, :]
# dane dla 301 osoby
# Out:
# PassengerId                                         301
# Survived                                              1
# Pclass                                                3
# Name           Kelly, Miss. Anna Katherine "Annie Kate"
# Sex                                              female
# Age                                                 NaN
# SibSp                                                 0
# Parch                                                 0
# Ticket                                             9234
# Fare                                               7.75
# Cabin                                               NaN
# Embarked                                              Q
# Name: 300, dtype: object

# %%
data.iloc[300, 1]
# Out:
# 1

# %%
# czyli pasażer nr 301 w kolumnie drugiej, czyli Survived ma wartość 1 , czyli True

# %%
data.loc[300, 'Survived']
# Out:
# 1

# %%
data[data['Age']< 5]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 63            64         0       3                     Skoog, Master. Harald
# 78            79         1       2             Caldwell, Master. Alden Gates
# 119          120         0       3         Andersson, Miss. Ellis Anna Maria
# 164          165         0       3              Panula, Master. Eino Viljami
# 171          172         0       3                      Rice, Master. Arthur
# 172          173         1       3              Johnson, Miss. Eleanor Ileen
# 183          184         1       2                 Becker, Master. Richard F
# ...

# %%
data['Age']< 5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10      True
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16      True
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869     True
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
data[data['Age']< 5].shape
# shape poda wymiary (ilość wierszy i kolumn)
# Out:
# (40, 12)

# %%
data[data['Age']< 5].shape[0]
#ilość wierszy tylko (element zerowy z tych co podał powyżej)
# Out:
# 40

# %%
np.sum(data['Age']< 5)
# Out:
# 40

# %%
data[data['Pclass'].isin([1])]
# ta wartość, nawet jak jedna, musi być umieszczona w liście
# oto ludzie z pierwszej klasy!! :D
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# 27            28         0       1
# 30            31         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 52            53         1       1
# 54            55         0       1
# 55            56         1       1
# 61            62         1       1
# 62            63         0       1
# 64            65         0       1
# 83            84         0       1
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 124          125         0       1
# ...

# %%
data[data['Pclass'].isin([1]) & data['Survived'].isin([0])]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 27            28         0       1
# 30            31         0       1
# 34            35         0       1
# 35            36         0       1
# 54            55         0       1
# 62            63         0       1
# 64            65         0       1
# 83            84         0       1
# 92            93         0       1
# 96            97         0       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 124          125         0       1
# 137          138         0       1
# 139          140         0       1
# 155          156         0       1
# 168          169         0       1
# 170          171         0       1
# 174          175         0       1
# 177          178         0       1
# 185          186         0       1
# 245          246         0       1
# 252          253         0       1
# ...

# %%
sns.distplot(data['Age'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-35c485796a80> in <module>()
# ----> 1 sns.distplot(data['Age'])
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     206     if hist:
#     207         if bins is None:
# --> 208             bins = min(_freedman_diaconis_bins(a), 50)
#     209         hist_kws.setdefault("alpha", 0.4)
#     210         hist_kws.setdefault("normed", norm_hist)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      32         return int(np.sqrt(a.size))
#      33     else:
# ---> 34         return int(np.ceil((a.max() - a.min()) / h))
#      35
#      36
#
# ValueError: cannot convert float NaN to integer

# %%
sns.distplot(data['Age']).dropna())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-c1950f2d953e> in <module>()
# ----> 1 sns.distplot(data['Age']).dropna()
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     206     if hist:
#     207         if bins is None:
# --> 208             bins = min(_freedman_diaconis_bins(a), 50)
#     209         hist_kws.setdefault("alpha", 0.4)
#     210         hist_kws.setdefault("normed", norm_hist)
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in _freedman_diaconis_bins(a)
#      32         return int(np.sqrt(a.size))
#      33     else:
# ---> 34         return int(np.ceil((a.max() - a.min()) / h))
#      35
#      36
#
# ValueError: cannot convert float NaN to integer

# %%
sns.distplot(data['Age'].dropna())
# usuwa braki danych

# %%
sns.distplot(data['Age'].dropna(), kde = False)
# kde = False usuwa linię

# %%
sns.distplot(data['Age'].dropna(), kde = False, fit = stats.gamma)
# dodajemy linię rozkładu normalnego

# %%
sns.distplot(data['Age'].dropna(), kde = False, fit = stats.gamma, hist = False)
# hist = False  usuwa słupki z wykresiku

# %%
sns.stripplot(data = data, x = 'Pclass', y = 'Age')

# %%
sns.stripplot(data = data, x = 'Pclass', y = 'Age', jitter = True)
# jitter rozrzuca nam te dane by poprawić widoczność

# %%
sns.stripplot(data = data, x = 'Pclass', y = 'Age', jitter = 0.1)
# zamiast wedle uznania rozrzuca w podany sposób

# %%
sns.swarmplot(data = data, x = 'Pclass', y = 'Age')
#

# %%
sns.swarmplot(data = data, x = 'Pclass', y = 'Age', hue = 'Survived')

# %%
sns.boxplot(data = data, x = "Sex", y = 'Age', hue = 'Survived')

# %%
sns.violinplot(data = data, x = "Sex", y = 'Age', hue = 'Survived')

# %%
sns.violinplot(data = data, x = "Sex", y = 'Age', hue = 'Survived', split = True)

# %%
sns.violinplot(data = data, x = "Sex", y = 'Age', hue = 'Survived', split = True)

sns.swarmplot(data = data, x = "Sex", y = 'Age', hue = 'Survived', color = 'red', alpha = 0.3)

# %%
sns.barplot(data = data, x = 'Sex', y = 'Survived', hue = 'Pclass')

# %%
sns.countplot(data = data, x = 'Pclass', hue = 'Survived')

# %%
sns.factorplot(data = data, x = 'Sex', y = 'Age', hue = 'Survived', col = 'Pclass', kind = 'swarm')

# %%
sns.factorplot(data = data, x = 'Sex', y = 'Age', hue = 'Survived', col = 'Pclass', kind = 'box')

# %%
sns.lmplot(data = data, x = 'Fare', y = 'Age')

# %%
sns.lmplot(data = data, x = 'Age', y='Survived', logistic = True, y_jitter = .05)

# %%
sns.lmplot(data = data, x = 'Age', y='Survived', logistic = True, y_jitter = .05, col = 'Sex')
