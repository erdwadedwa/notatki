# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://github.com/kpswps/py/raw/master/datasets/challenge_2/uniRanks/educational_attainment_supplementary_data.csv')

# %%
df
# Out:
#                                             country_name  \
# 0                                            Afghanistan
# 1                                            Afghanistan
# 2                                            Afghanistan
# 3                                            Afghanistan
# 4                                            Afghanistan
# 5                                            Afghanistan
# 6                                            Afghanistan
# 7                                            Afghanistan
# 8                                            Afghanistan
# 9                                            Afghanistan
# 10                                           Afghanistan
# 11                                           Afghanistan
# 12                                           Afghanistan
# 13                                           Afghanistan
# 14                                           Afghanistan
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79055 entries, 0 to 79054
# Data columns (total 29 columns):
# country_name    79052 non-null object
# series_name     79050 non-null object
# 1985            51843 non-null float64
# 1986            12 non-null float64
# 1987            3 non-null float64
# 1990            51846 non-null float64
# 1991            1 non-null float64
# 1992            3 non-null float64
# 1993            1 non-null float64
# 1995            51884 non-null float64
# 1996            3 non-null float64
# 1997            0 non-null float64
# 1998            47 non-null float64
# 1999            9 non-null float64
# 2000            51970 non-null float64
# 2001            225 non-null float64
# 2002            184 non-null float64
# 2003            55 non-null float64
# 2004            137 non-null float64
# 2005            52037 non-null float64
# 2006            204 non-null float64
# 2007            286 non-null float64
# ...

# %%
pd.isnull(df).sum()
# Out:
# country_name        3
# series_name         5
# 1985            27212
# 1986            79043
# 1987            79052
# 1990            27209
# 1991            79054
# 1992            79052
# 1993            79054
# 1995            27171
# 1996            79052
# 1997            79055
# 1998            79008
# 1999            79046
# 2000            27085
# 2001            78830
# 2002            78871
# 2003            79000
# 2004            78918
# 2005            27018
# 2006            78851
# 2007            78769
# 2008            78689
# 2009            78591
# 2010            26259
# 2011            78126
# 2012            77949
# 2013            77176
# 2015            79055
# dtype: int64

# %%
df['series_name']
# Out:
# 0        Barro-Lee: Average years of primary schooling,...
# 1        Barro-Lee: Average years of primary schooling,...
# 2        Barro-Lee: Average years of primary schooling,...
# 3        Barro-Lee: Average years of primary schooling,...
# 4        Barro-Lee: Average years of primary schooling,...
# 5        Barro-Lee: Average years of primary schooling,...
# 6        Barro-Lee: Average years of primary schooling,...
# 7        Barro-Lee: Average years of primary schooling,...
# 8        Barro-Lee: Average years of primary schooling,...
# 9        Barro-Lee: Average years of primary schooling,...
# 10       Barro-Lee: Average years of primary schooling,...
# 11       Barro-Lee: Average years of primary schooling,...
# 12       Barro-Lee: Average years of primary schooling,...
# 13       Barro-Lee: Average years of primary schooling,...
# 14       Barro-Lee: Average years of primary schooling,...
# 15       Barro-Lee: Average years of primary schooling,...
# ...

# %%
obciety = df.iloc[:-5, :]

# %%
obciety
# Out:
#       country_name                                        series_name  1985  \
# 0      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33
# 1      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03
# 2      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83
# 3      Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34
# 4      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54
# 5      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.52
# 6      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.17
# 7      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.66
# 8      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.44
# 9      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.28
# 10     Afghanistan  Barro-Lee: Average years of primary schooling,...  0.22
# ...

# %%
BezPustychKolumn = obciety.dropna( axis =1, how ='all')

# %%
BezPustychKolumn
# Out:
#       country_name                                        series_name  1985  \
# 0      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33
# 1      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03
# 2      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83
# 3      Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34
# 4      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54
# 5      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.52
# 6      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.17
# 7      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.66
# 8      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.44
# 9      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.28
# 10     Afghanistan  Barro-Lee: Average years of primary schooling,...  0.22
# ...

# %%
Odwrocona = BezPustychKolumn.T
Odwrocona
# Out:
#                                                           0      \
# country_name                                        Afghanistan
# series_name   Barro-Lee: Average years of primary schooling,...
# 1985                                                       0.33
# 1986                                                        NaN
# 1987                                                        NaN
# 1990                                                       0.44
# 1991                                                        NaN
# 1992                                                        NaN
# 1993                                                        NaN
# 1995                                                       0.57
# 1996                                                        NaN
# 1998                                                        NaN
# 1999                                                        NaN
# 2000                                                       0.75
# ...

# %%
Odwrocona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries, country_name to 2013
# Columns: 79050 entries, 0 to 79049
# dtypes: object(79050)
# memory usage: 16.3+ MB

# %%
pd.isnull(Odwrocona).sum()
# Out:
# 0        19
# 1        19
# 2        19
# 3        19
# 4        19
# 5        19
# 6        19
# 7        19
# 8        19
# 9        19
# 10       19
# 11       19
# 12       19
# 13       19
# 14       19
# 15       19
# 16       19
# 17       19
# 18       19
# 19       19
# 20       19
# 21       19
# 22       19
# 23       19
# 24       19
# 25       19
# 26       19
# 27       19
# 28       19
# 29       19
#          ..
# 79020    25
# 79021    24
# 79022    24
# 79023    24
# 79024    24
# 79025    24
# 79026    24
# 79027    24
# 79028    24
# 79029    24
# 79030    24
# 79031    24
# 79032    25
# 79033    25
# 79034    25
# 79035    24
# 79036    24
# 79037    24
# 79038    24
# 79039    24
# 79040    24
# 79041    24
# 79042    24
# 79043    24
# 79044    24
# 79045    24
# 79046    24
# 79047    24
# 79048    24
# 79049    24
# Length: 79050, dtype: int64

# %%
#Usuwam puste kolumny (dawne wiersze) - kategorie dla których nie ma danych
Odwrocona.dropna(axis=1, thresh=3)
# Out:
#                                                           0      \
# country_name                                        Afghanistan
# series_name   Barro-Lee: Average years of primary schooling,...
# 1985                                                       0.33
# 1986                                                        NaN
# 1987                                                        NaN
# 1990                                                       0.44
# 1991                                                        NaN
# 1992                                                        NaN
# 1993                                                        NaN
# 1995                                                       0.57
# 1996                                                        NaN
# 1998                                                        NaN
# 1999                                                        NaN
# 2000                                                       0.75
# ...

# %%
#Usuwam puste wiersze, bez odwracania (kategorie dla których nie ma danych)
BezPustychKolumnIPustychWierszy = BezPustychKolumn.dropna (axis=0, thresh=3)
BezPustychKolumnIPustychWierszy
# Out:
#       country_name                                        series_name  1985  \
# 0      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.33
# 1      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.03
# 2      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.83
# 3      Afghanistan  Barro-Lee: Average years of primary schooling,...  2.34
# 4      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.54
# 5      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.52
# 6      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.17
# 7      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.66
# 8      Afghanistan  Barro-Lee: Average years of primary schooling,...  0.44
# 9      Afghanistan  Barro-Lee: Average years of primary schooling,...  1.28
# 10     Afghanistan  Barro-Lee: Average years of primary schooling,...  0.22
# ...

# %%
BarroLee = BezPustychKolumnIPustychWierszy[BezPustychKolumnIPustychWierszy['series_name'].str.contains("Barro")]

# %%
BarroLee
# Out:
#       country_name                                        series_name  \
# 0      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 1      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 2      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 3      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 4      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 5      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 6      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 7      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 8      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 9      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 10     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 11     Afghanistan  Barro-Lee: Average years of primary schooling,...
# ...

# %%
UIS = BezPustychKolumnIPustychWierszy[~BezPustychKolumnIPustychWierszy['series_name'].str.contains("Barro")]

# %%
UIS
# Out:
#       country_name                                        series_name  1985  \
# 785        Albania  UIS: Mean years of schooling of the population...   NaN
# 786        Albania  UIS: Mean years of schooling of the population...   NaN
# 787        Albania  UIS: Mean years of schooling of the population...   NaN
# 788        Albania  UIS: Percentage of population age 25+ with a c...   NaN
# 789        Albania  UIS: Percentage of population age 25+ with a c...   NaN
# 790        Albania  UIS: Percentage of population age 25+ with a c...   NaN
# 791        Albania  UIS: Percentage of population age 25+ with a c...   NaN
# 792        Albania  UIS: Percentage of population age 25+ with a c...   NaN
# 793        Albania  UIS: Percentage of population age 25+ with a c...   NaN
# 794        Albania  UIS: Percentage of population age 25+ with a c...   NaN
# 795        Albania  UIS: Percentage of population age 25+ with a c...   NaN
# ...

# %%
UIS['series_name']
# Out:
# 785      UIS: Mean years of schooling of the population...
# 786      UIS: Mean years of schooling of the population...
# 787      UIS: Mean years of schooling of the population...
# 788      UIS: Percentage of population age 25+ with a c...
# 789      UIS: Percentage of population age 25+ with a c...
# 790      UIS: Percentage of population age 25+ with a c...
# 791      UIS: Percentage of population age 25+ with a c...
# 792      UIS: Percentage of population age 25+ with a c...
# 793      UIS: Percentage of population age 25+ with a c...
# 794      UIS: Percentage of population age 25+ with a c...
# 795      UIS: Percentage of population age 25+ with a c...
# 796      UIS: Percentage of population age 25+ with a c...
# 797      UIS: Percentage of population age 25+ with a d...
# 798      UIS: Percentage of population age 25+ with a d...
# 799      UIS: Percentage of population age 25+ with a d...
# 800      UIS: Percentage of population age 25+ with a d...
# ...

# %%
#UIS: Percentage of population age 25+ with at least completed primary education (ISCED 1 or higher)
ISCED_1_or_higher = UIS[UIS['series_name'].str.contains("ISCED 1 or higher")]
ISCED_1_or_higher
# Out:
#                country_name  \
# 821                 Albania
# 822                 Albania
# 823                 Albania
# 824                 Albania
# 1246                Algeria
# 1247                Algeria
# 1248                Algeria
# 1249                Algeria
# 1671                Andorra
# 1672                Andorra
# 1673                Andorra
# 1674                Andorra
# 2096              Argentina
# 2097              Argentina
# 2098              Argentina
# 2099              Argentina
# 2521                Armenia
# 2522                Armenia
# 2523                Armenia
# 2524                Armenia
# 4221             Azerbaijan
# 4222             Azerbaijan
# 4223             Azerbaijan
# 4224             Azerbaijan
# 4646           Bahamas, The
# 4647           Bahamas, The
# 4648           Bahamas, The
# 4649           Bahamas, The
# 5071                Bahrain
# 5072                Bahrain
# ...                     ...
# 73498                Uganda
# ...

# %%
UIS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6437 entries, 785 to 79049
# Data columns (total 27 columns):
# country_name    6437 non-null object
# series_name     6437 non-null object
# 1985            3 non-null float64
# 1986            12 non-null float64
# 1987            3 non-null float64
# 1990            6 non-null float64
# 1991            1 non-null float64
# 1992            3 non-null float64
# 1993            1 non-null float64
# 1995            44 non-null float64
# 1996            3 non-null float64
# 1998            47 non-null float64
# 1999            9 non-null float64
# 2000            130 non-null float64
# 2001            225 non-null float64
# 2002            184 non-null float64
# 2003            55 non-null float64
# 2004            137 non-null float64
# 2005            197 non-null float64
# 2006            204 non-null float64
# 2007            286 non-null float64
# 2008            366 non-null float64
# 2009            464 non-null float64
# ...

# %%
#UIS: Percentage of population age 25+ with at least completed primary education (ISCED 1 or higher). Male
ISCED_1_or_higher_male = UIS[UIS['series_name'].str.contains("(ISCED 1 or higher). Male")]
ISCED_1_or_higher_male
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# Empty DataFrame
# Columns: [country_name, series_name, 1985, 1986, 1987, 1990, 1991, 1992, 1993, 1995, 1996, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]
# Index: []
#
# [0 rows x 27 columns]

# %%
UIS_Male = UIS[UIS['series_name'].str.contains("Male")]
UIS_Male
# Out:
#              country_name                                        series_name  \
# 786               Albania  UIS: Mean years of schooling of the population...
# 789               Albania  UIS: Percentage of population age 25+ with a c...
# 792               Albania  UIS: Percentage of population age 25+ with a c...
# 795               Albania  UIS: Percentage of population age 25+ with a c...
# 799               Albania  UIS: Percentage of population age 25+ with a d...
# 803               Albania  UIS: Percentage of population age 25+ with at ...
# 807               Albania  UIS: Percentage of population age 25+ with at ...
# 811               Albania  UIS: Percentage of population age 25+ with at ...
# 815               Albania  UIS: Percentage of population age 25+ with at ...
# 819               Albania  UIS: Percentage of population age 25+ with at ...
# 823               Albania  UIS: Percentage of population age 25+ with at ...
# ...

# %%
UIS_Gender_Parity_Index = UIS[UIS['series_name'].str.contains("Gender Parity Index")]
UIS_Gender_Parity_Index
# Out:
#              country_name                                        series_name  \
# 798               Albania  UIS: Percentage of population age 25+ with a d...
# 802               Albania  UIS: Percentage of population age 25+ with at ...
# 806               Albania  UIS: Percentage of population age 25+ with at ...
# 810               Albania  UIS: Percentage of population age 25+ with at ...
# 814               Albania  UIS: Percentage of population age 25+ with at ...
# 818               Albania  UIS: Percentage of population age 25+ with at ...
# 822               Albania  UIS: Percentage of population age 25+ with at ...
# 826               Albania  UIS: Percentage of population age 25+ with at ...
# 1239              Algeria  UIS: Percentage of population age 25+ with at ...
# 1247              Algeria  UIS: Percentage of population age 25+ with at ...
# 1251              Algeria  UIS: Percentage of population age 25+ with at ...
# ...

# %%
UIS_Female = UIS[UIS['series_name'].str.contains("Female")]
UIS_Female
# Out:
#              country_name                                        series_name  \
# 785               Albania  UIS: Mean years of schooling of the population...
# 788               Albania  UIS: Percentage of population age 25+ with a c...
# 791               Albania  UIS: Percentage of population age 25+ with a c...
# 794               Albania  UIS: Percentage of population age 25+ with a c...
# 797               Albania  UIS: Percentage of population age 25+ with a d...
# 801               Albania  UIS: Percentage of population age 25+ with at ...
# 805               Albania  UIS: Percentage of population age 25+ with at ...
# 809               Albania  UIS: Percentage of population age 25+ with at ...
# 813               Albania  UIS: Percentage of population age 25+ with at ...
# 817               Albania  UIS: Percentage of population age 25+ with at ...
# 821               Albania  UIS: Percentage of population age 25+ with at ...
# ...

# %%
UIS_All_gender = UIS[UIS['series_name'].str.contains("Total")]
UIS_All_gender
# Out:
#              country_name                                        series_name  \
# 787               Albania  UIS: Mean years of schooling of the population...
# 790               Albania  UIS: Percentage of population age 25+ with a c...
# 793               Albania  UIS: Percentage of population age 25+ with a c...
# 796               Albania  UIS: Percentage of population age 25+ with a c...
# 800               Albania  UIS: Percentage of population age 25+ with a d...
# 804               Albania  UIS: Percentage of population age 25+ with at ...
# 808               Albania  UIS: Percentage of population age 25+ with at ...
# 812               Albania  UIS: Percentage of population age 25+ with at ...
# 816               Albania  UIS: Percentage of population age 25+ with at ...
# 820               Albania  UIS: Percentage of population age 25+ with at ...
# 824               Albania  UIS: Percentage of population age 25+ with at ...
# ...

# %%
UIS_Female.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1902 entries, 785 to 79047
# Data columns (total 27 columns):
# country_name    1902 non-null object
# series_name     1902 non-null object
# 1985            1 non-null float64
# 1986            4 non-null float64
# 1987            1 non-null float64
# 1990            2 non-null float64
# 1991            0 non-null float64
# 1992            1 non-null float64
# 1993            0 non-null float64
# 1995            13 non-null float64
# 1996            1 non-null float64
# 1998            14 non-null float64
# 1999            3 non-null float64
# 2000            40 non-null float64
# 2001            68 non-null float64
# 2002            56 non-null float64
# 2003            17 non-null float64
# 2004            43 non-null float64
# 2005            61 non-null float64
# 2006            64 non-null float64
# 2007            89 non-null float64
# 2008            113 non-null float64
# 2009            142 non-null float64
# ...

# %%
UIS_Male.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1902 entries, 786 to 79048
# Data columns (total 27 columns):
# country_name    1902 non-null object
# series_name     1902 non-null object
# 1985            1 non-null float64
# 1986            4 non-null float64
# 1987            1 non-null float64
# 1990            2 non-null float64
# 1991            0 non-null float64
# 1992            1 non-null float64
# 1993            0 non-null float64
# 1995            13 non-null float64
# 1996            1 non-null float64
# 1998            14 non-null float64
# 1999            3 non-null float64
# 2000            40 non-null float64
# 2001            68 non-null float64
# 2002            56 non-null float64
# 2003            17 non-null float64
# 2004            43 non-null float64
# 2005            61 non-null float64
# 2006            64 non-null float64
# 2007            89 non-null float64
# 2008            113 non-null float64
# 2009            142 non-null float64
# ...

# %%
UIS_All_gender.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1903 entries, 787 to 79049
# Data columns (total 27 columns):
# country_name    1903 non-null object
# series_name     1903 non-null object
# 1985            1 non-null float64
# 1986            4 non-null float64
# 1987            1 non-null float64
# 1990            2 non-null float64
# 1991            1 non-null float64
# 1992            1 non-null float64
# 1993            1 non-null float64
# 1995            13 non-null float64
# 1996            1 non-null float64
# 1998            14 non-null float64
# 1999            3 non-null float64
# 2000            40 non-null float64
# 2001            68 non-null float64
# 2002            56 non-null float64
# 2003            17 non-null float64
# 2004            43 non-null float64
# 2005            61 non-null float64
# 2006            64 non-null float64
# 2007            90 non-null float64
# 2008            113 non-null float64
# 2009            142 non-null float64
# ...

# %%
UIS_Gender_Parity_Index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 798 to 79026
# Data columns (total 27 columns):
# country_name    730 non-null object
# series_name     730 non-null object
# 1985            0 non-null float64
# 1986            0 non-null float64
# 1987            0 non-null float64
# 1990            0 non-null float64
# 1991            0 non-null float64
# 1992            0 non-null float64
# 1993            0 non-null float64
# 1995            5 non-null float64
# 1996            0 non-null float64
# 1998            5 non-null float64
# 1999            0 non-null float64
# 2000            10 non-null float64
# 2001            21 non-null float64
# 2002            16 non-null float64
# 2003            4 non-null float64
# 2004            8 non-null float64
# 2005            14 non-null float64
# 2006            12 non-null float64
# 2007            18 non-null float64
# 2008            27 non-null float64
# 2009            38 non-null float64
# ...
