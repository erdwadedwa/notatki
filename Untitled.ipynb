# %%
# w odznaczonej (niebieskiej) komórce wciskamy 4, pojawiają się ####

# %%
import os 
import os.path as op
import matplotlib.pyplot

# %%
os.getcwd()
# Out:
# 'C:\\Users\\apiotro8'

# %%
# os.chdir('')
# Out:
#   File "<ipython-input-6-f23075a8f7a2>", line 1
#     os.chdir('C:\Users\apiotro8\Documents')
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  'AppData',
#  'Contacts',
#  'Cookies',
#  'Dane aplikacji',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Menu Start',
#  'Moje dokumenty',
#  'Music',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TM.blf',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'ntuser.pol',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Szablony',
#  'Untitled.ipynb',
#  'Ustawienia lokalne',
#  'Videos']

# %%
#os.chdir('C:\Users\apiotro8\Documents\KP SWPS')

# %%
if not op.exists(mypath): 
    os.makedirs(mypath)

# %%
mypath = 'C:\Users\apiotro8\Documents'
# Out:
#   File "<ipython-input-11-f86ba982c165>", line 1
#     mypath = 'C:\Users\apiotro8\Documents'
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
op.exists(mypath)

# %%
mypath

# %%
os.chdir(mypath)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\apiotro8'

# %%
startdir = ''

# %%
mydir = op.join()

# %%
myzip = 'https://github.com/kpswps/py/raw/master/datasets/college-salaries.zip'

# %%
myzip
# Out:
# 'https://github.com/kpswps/py/raw/master/datasets/college-salaries.zip'

# %%
#import urllib.request

# %%
from urllib.request import urlretrieve

# %%
os.getcwd()
# Out:
# 'C:\\Users\\apiotro8'

# %%
zipname = 'college-salaries.zip'

# %%
filepath = op.join(os.getcwd(), zipname)

# %%
urlretrieve(myzip, filepath )
# Out:
# ('C:\\Users\\apiotro8\\college-salaries.zip',
#  <http.client.HTTPMessage at 0x14e86fe240>)

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  'AppData',
#  'college-salaries.zip',
#  'Contacts',
#  'Cookies',
#  'Dane aplikacji',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Menu Start',
#  'Moje dokumenty',
#  'Music',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TM.blf',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'ntuser.pol',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Szablony',
#  'Untitled.ipynb',
#  'Ustawienia lokalne',
#  'Videos']

# %%
import zipfile

# %%
with zipfile.ZipFile(zipname, 'r') as zip_ref:
    zip_ref.extractall()

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.condarc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  'AppData',
#  'college-salaries',
#  'college-salaries.zip',
#  'Contacts',
#  'Cookies',
#  'Dane aplikacji',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Menu Start',
#  'Moje dokumenty',
#  'Music',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TM.blf',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{bbed3e3b-0b41-11e3-8249-d6927d06400b}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'ntuser.pol',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Szablony',
#  'Untitled.ipynb',
#  'Ustawienia lokalne',
#  'Videos',
#  '__MACOSX']

# %%
smietniczek = os.listdir('college-salaries')

# %%
smietniczek
# Out:
# ['.DS_Store',
#  'degrees-that-pay-back.csv',
#  'hummus.jpg',
#  'iranistykaIstopien╠ü_program.xls',
#  'mg.jpg',
#  'salaries-by-college-type.csv',
#  'salaries-by-region.csv']

# %%
from PIL import Image

# %%
# %matplotlib inline

# %%
datadir = op.join(os.getcwd(), 
                  'college-salaries',
                 smietniczek[2])

# %%
smietniczek[2]
# Out:
# 'hummus.jpg'

# %%
pil_im = Image.open(datadir, 'r')

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x720 at 0x14E5215128>

# %%
smietniczek[-3]
# Out:
# 'mg.jpg'

# %%
datadir = op.join(os.getcwd(), 
                  'college-salaries',
                 smietniczek[-3])

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x720 at 0x14E9CCD3C8>
