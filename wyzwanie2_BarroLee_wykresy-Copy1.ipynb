# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('https://github.com/kpswps/py/raw/master/datasets/challenge_2/uniRanks/educational_attainment_supplementary_data.csv')

# %%
#df

# %%
#df.info()

# %%
#pd.isnull(df).sum()

# %%
#df['series_name']

# %%
obciety = df.iloc[:-5, :]

# %%
#obciety

# %%
#obciety.info()

# %%
#usuwam puste kolumny - bez jakichkolwiek danych
BezPustychKolumn = obciety.dropna( axis =1, how ='all')

# %%
#BezPustychKolumn

# %%
#BezPustychKolumn.info()

# %%
#Usuwam puste wiersze (kategorie dla których nie ma danych)
BezPustychKolumnIPustychWierszy = BezPustychKolumn.dropna (axis=0, thresh=3)
#BezPustychKolumnIPustychWierszy

# %%
#BezPustychKolumnIPustychWierszy.info()

# %%
BarroLee = BezPustychKolumnIPustychWierszy[BezPustychKolumnIPustychWierszy['series_name'].str.contains("Barro")]

# %%
#BarroLee.info()

# %%
BarroLee = BarroLee.dropna( axis =1, how ='all')
#sns.stripplot(data=titanic, x="Pclass", y="Age")BarroLee.info()

# %%
BarroLee = BarroLee.dropna( axis =0, thresh = 3 )
#BarroLee.info()

# %%
#BarroLee = BarroLee.pivot(index='country_name', columns='series_name')

# %%
BarroLee
# Out:
#       country_name                                        series_name  \
# 0      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 1      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 2      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 3      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 4      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 5      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 6      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 7      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 8      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 9      Afghanistan  Barro-Lee: Average years of primary schooling,...
# 10     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 11     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 12     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 13     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 14     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 15     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 16     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 17     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 18     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 19     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 20     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 21     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 22     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 23     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 24     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 25     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 26     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 27     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 28     Afghanistan  Barro-Lee: Average years of primary schooling,...
# 29     Afghanistan  Barro-Lee: Average years of primary schooling,...
# ...            ...                                                ...
# 78955     Zimbabwe  Barro-Lee: Population in thousands, age 15+, f...
# 78956     Zimbabwe  Barro-Lee: Population in thousands, age 15+, t...
# 78957     Zimbabwe  Barro-Lee: Population in thousands, age 15-19,...
# 78958     Zimbabwe  Barro-Lee: Population in thousands, age 15-19,...
# 78959     Zimbabwe  Barro-Lee: Population in thousands, age 20-24,...
# 78960     Zimbabwe  Barro-Lee: Population in thousands, age 20-24,...
# 78961     Zimbabwe  Barro-Lee: Population in thousands, age 25+, f...
# 78962     Zimbabwe  Barro-Lee: Population in thousands, age 25+, t...
# 78963     Zimbabwe  Barro-Lee: Population in thousands, age 25-29,...
# 78964     Zimbabwe  Barro-Lee: Population in thousands, age 25-29,...
# 78965     Zimbabwe  Barro-Lee: Population in thousands, age 30-34,...
# 78966     Zimbabwe  Barro-Lee: Population in thousands, age 30-34,...
# 78967     Zimbabwe  Barro-Lee: Population in thousands, age 35-39,...
# 78968     Zimbabwe  Barro-Lee: Population in thousands, age 35-39,...
# 78969     Zimbabwe  Barro-Lee: Population in thousands, age 40-44,...
# 78970     Zimbabwe  Barro-Lee: Population in thousands, age 40-44,...
# 78971     Zimbabwe  Barro-Lee: Population in thousands, age 45-49,...
# 78972     Zimbabwe  Barro-Lee: Population in thousands, age 45-49,...
# 78973     Zimbabwe  Barro-Lee: Population in thousands, age 50-54,...
# 78974     Zimbabwe  Barro-Lee: Population in thousands, age 50-54,...
# 78975     Zimbabwe  Barro-Lee: Population in thousands, age 55-59,...
# 78976     Zimbabwe  Barro-Lee: Population in thousands, age 55-59,...
# 78977     Zimbabwe  Barro-Lee: Population in thousands, age 60-64,...
# 78978     Zimbabwe  Barro-Lee: Population in thousands, age 60-64,...
# 78979     Zimbabwe  Barro-Lee: Population in thousands, age 65-69,...
# 78980     Zimbabwe  Barro-Lee: Population in thousands, age 65-69,...
# 78981     Zimbabwe  Barro-Lee: Population in thousands, age 70-74,...
# 78982     Zimbabwe  Barro-Lee: Population in thousands, age 70-74,...
# 78983     Zimbabwe  Barro-Lee: Population in thousands, age 75+, f...
# 78984     Zimbabwe  Barro-Lee: Population in thousands, age 75+, t...
#
#           1985     1990     1995     2000     2005     2010
# 0         0.33     0.44     0.57     0.75     0.86     1.27
# 1         1.03     1.26     1.54     2.01     2.18     2.64
# 2         0.83     0.95     1.26     1.92     1.01     2.45
# 3         2.34     2.22     2.37     3.83     2.26     3.55
# 4         0.54     0.92     0.94     1.26     2.00     1.29
# 5         1.52     2.51     2.27     2.48     3.93     2.64
# 6         0.17     0.25     0.37     0.48     0.63     0.81
# 7         0.66     0.85     1.14     1.38     1.69     2.19
# 8         0.44     0.54     0.92     0.94     1.26     1.92
# 9         1.28     1.52     2.51     2.27     2.48     3.93
# 10        0.22     0.44     0.54     0.92     0.94     1.26
# 11        0.95     1.28     1.52     2.51     2.27     2.48
# 12        0.22     0.22     0.44     0.54     0.92     0.94
# 13        0.95     0.95     1.28     1.52     2.51     2.27
# 14        0.06     0.22     0.22     0.44     0.54     0.92
# 15        0.36     0.95     0.95     1.28     1.52     2.51
# 16        0.06     0.06     0.22     0.22     0.44     0.54
# 17        0.36     0.36     0.95     0.95     1.28     1.52
# 18        0.02     0.06     0.06     0.22     0.22     0.44
# 19        0.24     0.36     0.36     0.95     0.95     1.28
# 20        0.02     0.02     0.06     0.06     0.22     0.22
# 21        0.24     0.24     0.36     0.36     0.95     0.95
# 22        0.01     0.02     0.02     0.06     0.06     0.22
# 23        0.14     0.24     0.24     0.36     0.36     0.95
# 24        0.01     0.01     0.02     0.02     0.06     0.06
# 25        0.14     0.14     0.24     0.24     0.36     0.36
# 26        0.01     0.02     0.02     0.03     0.03     0.06
# 27        0.06     0.15     0.15     0.25     0.25     0.37
# 28        0.01     0.01     0.01     0.02     0.02     0.03
# 29        0.06     0.06     0.11     0.14     0.21     0.24
# ...        ...      ...      ...      ...      ...      ...
# 78955  2345.00  2889.00  3339.00  3706.00  3961.00  4182.00
# 78956  4629.00  5706.00  6533.00  7233.00  7810.00  8347.00
# 78957   487.00   591.00   682.00   802.00   870.00   861.00
# 78958   973.00  1181.00  1362.00  1603.00  1740.00  1722.00
# 78959   399.00   491.00   563.00   651.00   775.00   843.00
# 78960   794.00   976.00  1118.00  1296.00  1546.00  1685.00
# 78961  1459.00  1807.00  2094.00  2253.00  2316.00  2478.00
# 78962  2862.00  3549.00  4053.00  4334.00  4524.00  4940.00
# 78963   324.00   404.00   450.00   478.00   560.00   681.00
# 78964   642.00   800.00   883.00   951.00  1131.00  1379.00
# 78965   262.00   328.00   369.00   361.00   346.00   425.00
# 78966   515.00   648.00   718.00   707.00   716.00   897.00
# 78967   175.00   263.00   304.00   304.00   254.00   238.00
# 78968   345.00   518.00   588.00   583.00   513.00   524.00
# 78969   158.00   175.00   247.00   262.00   230.00   183.00
# 78970   315.00   346.00   476.00   496.00   443.00   382.00
# 78971   128.00   157.00   165.00   221.00   214.00   181.00
# 78972   254.00   312.00   320.00   417.00   402.00   351.00
# 78973   108.00   125.00   149.00   152.00   192.00   182.00
# 78974   212.00   248.00   291.00   287.00   357.00   338.00
# 78975    92.00   104.00   118.00   138.00   136.00   171.00
# 78976   179.00   203.00   230.00   264.00   253.00   312.00
# 78977    71.00    87.00    97.00   109.00   125.00   123.00
# 78978   137.00   167.00   186.00   209.00   235.00   224.00
# 78979    60.00    64.00    78.00    87.00    97.00   111.00
# 78980   115.00   122.00   147.00   163.00   181.00   204.00
# 78981    39.00    51.00    54.00    66.00    73.00    81.00
# 78982    73.00    95.00   101.00   122.00   134.00   148.00
# 78983    42.00    49.00    63.00    75.00    89.00   102.00
# 78984    75.00    90.00   113.00   135.00   159.00   181.00
#
# [51840 rows x 8 columns]

# %%
BarroLee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51840 entries, 0 to 78984
# Data columns (total 8 columns):
# country_name    51840 non-null object
# series_name     51840 non-null object
# 1985            51840 non-null float64
# 1990            51840 non-null float64
# 1995            51840 non-null float64
# 2000            51840 non-null float64
# 2005            51840 non-null float64
# 2010            51840 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 3.6+ MB

# %% [raw]
# sns.stripplot(data=BarroLee, x="1985, Barro-Lee: Average years of primary schooling, age 15+, female", y="Age")

# %%
AverageYearsOf_PrimSchooling = BarroLee[BarroLee['series_name'].str.contains("Barro-Lee: Average years of primary schooling")]
#AverageYearsOf_PrimSchooling.info()

# %%
#AverageYearsOf_PrimSchooling_bezPlusa = BarroLee[~BarroLee['series_name'].str.contains("+")]

# %%
AverageYearsOf_SecSchooling = BarroLee[BarroLee['series_name'].str.contains("Barro-Lee: Average years of secondary schooling")]
#AverageYearsOf_SecSchooling.info()

# %%
AverageYearsOf_TerSchooling = BarroLee[BarroLee['series_name'].str.contains("Barro-Lee: Average years of tertiary schooling")]
#AverageYearsOf_TerSchooling.info()

# %%
AverageYearsOf_TotalSchooling = BarroLee[BarroLee['series_name'].str.contains("Barro-Lee: Average years of total schooling")]
#AverageYearsOf_TotalSchooling.info()

# %%
#PrimSchooling_Female = AverageYearsOf_PrimSchooling[AverageYearsOf_PrimSchooling['series_name'].str.contains(", female")]
#PrimSchooling_Female.info()

# %%
#PrimSchooling_Total = AverageYearsOf_PrimSchooling[AverageYearsOf_PrimSchooling['series_name'].str.contains("total")]
#PrimSchooling_Total.info()

# %%
#BL_Schooling_Male = BarroLee[BarroLee['series_name'].str.contains(", male")]
#BL_Schooling_Male.info()

# %%
#BL_Schooling_Female = BarroLee[BarroLee['series_name'].str.contains(", female")]
#BL_Schooling_Female.info()

# %%
#BL_Schooling_Total = BarroLee[BarroLee['series_name'].str.contains(", total")]
#BL_Schooling_Total.info()

# %%
Poland = BarroLee[BarroLee['country_name'].str.contains('Poland')]
Poland.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 360 entries, 56100 to 56459
# Data columns (total 8 columns):
# country_name    360 non-null object
# series_name     360 non-null object
# 1985            360 non-null float64
# 1990            360 non-null float64
# 1995            360 non-null float64
# 2000            360 non-null float64
# 2005            360 non-null float64
# 2010            360 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 25.3+ KB

# %%
#Poland

# %%
#sns.distplot(Poland['1985'])

# %%
#BarroLee.to_csv('BarroLee.csv')

# %%
AverageYearsOf_PrimSchooling_15up_total = BarroLee[BarroLee['series_name'].str.contains("Average years of primary schooling, age 15+, total")]
AverageYearsOf_PrimSchooling_15up_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 8 columns):
# country_name    0 non-null object
# series_name     0 non-null object
# 1985            0 non-null float64
# 1990            0 non-null float64
# 1995            0 non-null float64
# 2000            0 non-null float64
# 2005            0 non-null float64
# 2010            0 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 0.0+ bytes
