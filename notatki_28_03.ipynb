# %%
s2 = {'ruskie' : 4.50, 'zupa' : 2.50}
s2
# Out:
# {'ruskie': 4.5, 'zupa': 2.5}

# %%
s2['ruskie']
# Out:
# 4.5

# %%
s2['kawior'] = 10.3

# %%
s2
# Out:
# {'kawior': 10.3, 'ruskie': 4.5, 'zupa': 2.5}

# %%
slowmik
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a7b50b8521ef> in <module>()
# ----> 1 slowmik
#
# NameError: name 'slowmik' is not defined

# %%
slownik['produkt']= 'Chlebek'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2aeb9a6aa055> in <module>()
# ----> 1 slownik['produkt']= 'Chlebek'
#
# NameError: name 'slownik' is not defined

# %%
slownik = {'produkt' : 'Chlebek'}

# %%
slownik['gluten'] = True

# %%
slownik['gluten']
# Out:
# True

# %%
slownik['cena']= 5.59

# %%
slownik
# Out:
# {'cena': 5.59, 'gluten': True, 'produkt': 'Chlebek'}

# %%
slownik['skład'] = ['mąka', 'drożdże', 'woda', 'sól']

# %%
slownik
# Out:
# {'cena': 5.59,
#  'gluten': True,
#  'produkt': 'Chlebek',
#  'skład': ['mąka', 'drożdże', 'woda', 'sól']}

# %%
slownik['skład'][0]
# Out:
# 'mąka'

# %%
type(slownik)
# Out:
# dict

# %%
slownik.keys()
# Out:
# dict_keys(['produkt', 'gluten', 'cena', 'skład'])

# %%
slownik.keys()[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-673bc5c13dcf> in <module>()
# ----> 1 slownik.keys()[0]
#
# TypeError: 'dict_keys' object does not support indexing

# %%
list(slownik.keys())
# Out:
# ['produkt', 'gluten', 'cena', 'skład']

# %%
slownik.values()
# Out:
# dict_values(['Chlebek', True, 5.59, ['mąka', 'drożdże', 'woda', 'sól']])

# %%
list(slownik.values())
# Out:
# ['Chlebek', True, 5.59, ['mąka', 'drożdże', 'woda', 'sól']]

# %%
list(slownik.values())[-1]
# Out:
# ['mąka', 'drożdże', 'woda', 'sól']

# %%
dane = {}

# %%
dane['numer'] = [1,2,3,4,5]

# %%
dane['imię'] = ['Beatka', 'Jarek', 'Zbyszek', 'Mariuszek', 'Tonio']

# %%
dane['zarobki'] = [10000, 20000, 15000, 17000, 20000]

# %%
import pandas as pd

# %%
pd.DataFrame(dane, columns =['numer', 'imię', 'zarobki'])
# Out:
#    numer       imię  zarobki
# 0      1     Beatka    10000
# 1      2      Jarek    20000
# 2      3    Zbyszek    15000
# 3      4  Mariuszek    17000
# 4      5      Tonio    20000

# %%
#########################

# %%
https://github.com/kpswps/py/raw/master/datasets/s01_e08.zip

# %%
import os
import os.path as op

# %%
os.getcwd()
# Out:
# 'C:\\Users\\apiotro8'

# %%
sciezka = 'C:\\Users\\apiotro8\\files'
if not op.exists(sciezka): 
    os.makedirs(sciezka)

# %%
op.exists(sciezka)
# Out:
# True

# %%
myzip = 'https://github.com/kpswps/py/raw/master/datasets/s01_e08.zip'

# %%
zipname = 's01_e08.zip'

# %%
filepath = op.join(os.getcwd(),zipname)

# %%
filepath
# Out:
# 'C:\\Users\\apiotro8\\s01_e08.zip'

# %%
mydir = op.join(sciezka, 's01_e08')

# %%
mydir
# Out:
# 'C:\\Users\\apiotro8\\files\\s01_e08'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\apiotro8'

# %%
os.chdir(sciezka)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\apiotro8\\files'

# %%
filepath = op.join(os.getcwd(),zipname)

# %%
filepath
# Out:
# 'C:\\Users\\apiotro8\\files\\s01_e08.zip'

# %%
from urllib.request import urlretrieve

urlretrieve(myzip, filepath)
# Out:
# ('C:\\Users\\apiotro8\\files\\s01_e08.zip',
#  <http.client.HTTPMessage at 0xe67e562208>)

# %%
import zipfile 

with zipfile.ZipFile(zipname, 'r') as zip_ref:
    zip_ref.extractall()

# %%
os.listdir('files')
# Out:
# ['(2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making.pdf',
#  '.DS_Store',
#  '.html',
#  '10.1523@jneurosci.2220-04.2004.pdf',
#  '100px-Coat_of_arms_of_Norway.svg.png',
#  '100px-Europe_orthographic_Caucasus_Urals_boundary_%28with_borders%29.svg.png',
#  '100px-Flag_of_La_Francophonie.svg.png',
#  '100px-Nordiske-flag.jpg',
#  '1042px-Summer_evening_at_Lovatnet%2C_Stryn%2C_Norway%2C_2013_June_-_3.jpg',
#  '11px-Decrease_Positive.svg.png',
#  '11px-Increase2.svg.png',
#  '11px-Increase_Negative.svg.png',
#  '11px-Loudspeaker.svg.png',
#  '12-brettspill-for-hele-familien-1.13974726.html',
#  '120px-08-08-01_Fl%C3%B8yen_utsikt.jpg',
#  '120px-Akureyri_rainbow.jpg',
#  '120px-Carte_du_Conseil_de_l%27Europe.png',
#  '120px-Hafnarfj%C3%B6r%C3%B0urHarbourView.JPG',
#  '120px-Hamraborgin_%C3%AD_K%C3%B3pavogi.JPG',
#  '120px-Lotnicza_panorama_Warszawy.jpg',
#  '120px-Neighborhood_of_Oslo_arial.jpg',
# ...

# %%
import numpy as np

# %%
liczby = np.random.randint(-100,101, 1000) # od -100 do 100 losujemy 1000 elementów

# %%
liczby
# Out:
# array([  63,  -79,   54,   58,   15,  -81,  -26,   17,  -91,   71,   69,
#         -77,   -9,  -34,    5,   75,   38,  -88,   16, -100,    6,  -44,
#          39,    2,   24,  -67,  -43,  -85,   98,   83,  -58,  -50,   -5,
#          26,   45,  -35,  -25,   93,    4,  -76,  -88,   69,    3,   77,
#          16,   39,   -3,  -67,   -9,  -62,  -37,   67,   60,  -97,  -58,
#         -25,   93,    5,  -12,   44,  -32,  -60,  -55,   -7,   17,   74,
#          33,  -67, -100,   28,    5,  -68,  -64,   69,  -10,  -60,  -10,
#         -97,  -69,   32,  -35,   77,  -94,   38,   81,   53,  -81,  -53,
#         -30,   73,   33,   55,   85,  -79,   88,   33,  -88,  -32,  -93,
#          -9,   55,  -12,   -5,    9,  -55,   53,  -81,   51,   60,   -4,
#          35,    1,   46,   39,  -24,  -16,   51,   53,  -65,  -44,  -42,
#         -54,  -84,  -10,  -33,   67,   60,  -36,   64,   24,  100,   74,
#         -46,  -88,   89,  100,  -38,   -7,  -17,  -71,   82,  -82,  -32,
# ...

# %%
liczby = list(np.random.randint(-100,101, 1000)) # od -100 do 100 losujemy 1000 elementów

# %%
liczby
# Out:
# [53,
#  -9,
#  -67,
#  -9,
#  10,
#  72,
#  -21,
#  29,
#  7,
#  16,
#  60,
#  -17,
#  -56,
#  21,
#  -88,
#  10,
#  -37,
#  46,
#  21,
#  -11,
#  -2,
#  72,
#  -44,
#  17,
#  80,
#  -98,
#  54,
#  -73,
#  66,
#  39,
#  -62,
#  62,
#  -61,
#  93,
#  42,
#  -61,
#  -29,
#  24,
#  1,
#  -63,
#  -29,
#  58,
#  30,
#  21,
#  99,
#  -27,
#  -95,
#  -16,
#  77,
#  11,
#  -67,
#  93,
#  -69,
#  -68,
#  42,
#  -42,
#  91,
#  96,
#  57,
#  -94,
#  -4,
#  41,
#  -97,
#  79,
#  34,
#  -31,
#  -61,
#  57,
#  75,
#  -10,
#  -27,
#  -13,
#  -55,
#  -44,
#  61,
#  -30,
#  -58,
#  54,
#  -44,
#  -45,
#  1,
#  -81,
#  -98,
#  91,
#  -8,
#  88,
#  -18,
#  95,
#  13,
#  17,
#  89,
#  51,
#  9,
#  -30,
#  -61,
#  90,
#  -71,
#  -81,
#  55,
#  -30,
#  -28,
#  60,
#  78,
#  -7,
#  59,
#  -57,
#  -14,
#  56,
#  80,
#  -55,
#  50,
#  71,
#  68,
#  -64,
#  -48,
#  100,
#  -23,
#  -94,
#  42,
#  94,
#  -89,
#  36,
#  -31,
#  -99,
#  18,
#  -54,
#  64,
#  -16,
#  -19,
#  -36,
#  -74,
#  -3,
#  -3,
#  -16,
# ...

# %%
for each in liczby:
    print(each)
# Out:
# 53
# -9
# -67
# -9
# 10
# 72
# -21
# 29
# 7
# 16
# 60
# -17
# -56
# 21
# -88
# 10
# -37
# 46
# 21
# -11
# -2
# 72
# -44
# 17
# 80
# -98
# 54
# -73
# 66
# 39
# -62
# 62
# -61
# 93
# 42
# -61
# -29
# 24
# 1
# -63
# -29
# 58
# 30
# 21
# 99
# -27
# -95
# -16
# 77
# 11
# -67
# 93
# -69
# -68
# 42
# -42
# 91
# 96
# 57
# -94
# -4
# 41
# -97
# 79
# 34
# -31
# -61
# 57
# 75
# -10
# -27
# -13
# -55
# -44
# 61
# -30
# -58
# 54
# -44
# -45
# 1
# -81
# -98
# 91
# -8
# 88
# -18
# 95
# 13
# 17
# 89
# 51
# 9
# -30
# -61
# 90
# -71
# -81
# 55
# -30
# -28
# 60
# 78
# -7
# 59
# -57
# -14
# 56
# 80
# -55
# 50
# 71
# 68
# -64
# -48
# 100
# -23
# -94
# 42
# 94
# -89
# 36
# -31
# -99
# 18
# -54
# 64
# -16
# -19
# -36
# -74
# -3
# -3
# -16
# 1
# -54
# 27
# -19
# -77
# 5
# 57
# -52
# -24
# 70
# 50
# -40
# 21
# -70
# -86
# -97
# 19
# 12
# 82
# -96
# 22
# 82
# 57
# 6
# -84
# 10
# -21
# -91
# -89
# -24
# -69
# 85
# -25
# -85
# 28
# 27
# -58
# -28
# -100
# -23
# -90
# 12
# -55
# 15
# 23
# -82
# -49
# -73
# 47
# ...

# %%
for each in liczby:
    print(each*each
         )
# Out:
# 2809
# 81
# 4489
# 81
# 100
# 5184
# 441
# 841
# 49
# 256
# 3600
# 289
# 3136
# 441
# 7744
# 100
# 1369
# 2116
# 441
# 121
# 4
# 5184
# 1936
# 289
# 6400
# 9604
# 2916
# 5329
# 4356
# 1521
# 3844
# 3844
# 3721
# 8649
# 1764
# 3721
# 841
# 576
# 1
# 3969
# 841
# 3364
# 900
# 441
# 9801
# 729
# 9025
# 256
# 5929
# 121
# 4489
# 8649
# 4761
# 4624
# 1764
# 1764
# 8281
# 9216
# 3249
# 8836
# 16
# 1681
# 9409
# 6241
# 1156
# 961
# 3721
# 3249
# 5625
# 100
# 729
# 169
# 3025
# 1936
# 3721
# 900
# 3364
# 2916
# 1936
# 2025
# 1
# 6561
# 9604
# 8281
# 64
# 7744
# 324
# 9025
# 169
# 289
# 7921
# 2601
# 81
# 900
# 3721
# 8100
# 5041
# 6561
# 3025
# 900
# 784
# 3600
# 6084
# 49
# 3481
# 3249
# 196
# 3136
# 6400
# 3025
# 2500
# 5041
# 4624
# 4096
# 2304
# 10000
# 529
# 8836
# 1764
# 8836
# 7921
# 1296
# 961
# 9801
# 324
# 2916
# 4096
# 256
# 361
# 1296
# 5476
# 9
# 9
# 256
# 1
# 2916
# 729
# 361
# 5929
# 25
# 3249
# 2704
# 576
# 4900
# 2500
# 1600
# 441
# 4900
# 7396
# 9409
# 361
# 144
# 6724
# ...

# %%
duze = []
male = []

# %%
for each in liczby:
    if each >= 0:
        duze.append(each)
    else:
        male.append(each)

# %%
duze
# Out:
# [53,
#  10,
#  72,
#  29,
#  7,
#  16,
#  60,
#  21,
#  10,
#  46,
#  21,
#  72,
#  17,
#  80,
#  54,
#  66,
#  39,
#  62,
#  93,
#  42,
#  24,
#  1,
#  58,
#  30,
#  21,
#  99,
#  77,
#  11,
#  93,
#  42,
#  91,
#  96,
#  57,
#  41,
#  79,
#  34,
#  57,
#  75,
#  61,
#  54,
#  1,
#  91,
#  88,
#  95,
#  13,
#  17,
#  89,
#  51,
#  9,
#  90,
#  55,
#  60,
#  78,
#  59,
#  56,
#  80,
#  50,
#  71,
#  68,
#  100,
#  42,
#  94,
#  36,
#  18,
#  64,
#  1,
#  27,
#  5,
#  57,
#  70,
#  50,
#  21,
#  19,
#  12,
#  82,
#  22,
#  82,
#  57,
#  6,
#  10,
#  85,
#  28,
#  27,
#  12,
#  15,
#  23,
#  47,
#  87,
#  25,
#  46,
#  18,
#  70,
#  89,
#  80,
#  67,
#  26,
#  46,
#  90,
#  6,
#  29,
#  93,
#  30,
#  95,
#  45,
#  2,
#  63,
#  48,
#  19,
#  32,
#  84,
#  13,
#  37,
#  24,
#  60,
#  8,
#  83,
#  33,
#  87,
#  42,
#  85,
#  77,
#  21,
#  44,
#  33,
#  84,
#  35,
#  76,
#  94,
#  41,
#  37,
#  73,
#  73,
#  96,
#  3,
#  15,
#  92,
#  94,
#  41,
#  14,
#  65,
#  31,
#  74,
#  81,
#  6,
# ...

# %%
male
# Out:
# [-9,
#  -67,
#  -9,
#  -21,
#  -17,
#  -56,
#  -88,
#  -37,
#  -11,
#  -2,
#  -44,
#  -98,
#  -73,
#  -62,
#  -61,
#  -61,
#  -29,
#  -63,
#  -29,
#  -27,
#  -95,
#  -16,
#  -67,
#  -69,
#  -68,
#  -42,
#  -94,
#  -4,
#  -97,
#  -31,
#  -61,
#  -10,
#  -27,
#  -13,
#  -55,
#  -44,
#  -30,
#  -58,
#  -44,
#  -45,
#  -81,
#  -98,
#  -8,
#  -18,
#  -30,
#  -61,
#  -71,
#  -81,
#  -30,
#  -28,
#  -7,
#  -57,
#  -14,
#  -55,
#  -64,
#  -48,
#  -23,
#  -94,
#  -89,
#  -31,
#  -99,
#  -54,
#  -16,
#  -19,
#  -36,
#  -74,
#  -3,
#  -3,
#  -16,
#  -54,
#  -19,
#  -77,
#  -52,
#  -24,
#  -40,
#  -70,
#  -86,
#  -97,
#  -96,
#  -84,
#  -21,
#  -91,
#  -89,
#  -24,
#  -69,
#  -25,
#  -85,
#  -58,
#  -28,
#  -100,
#  -23,
#  -90,
#  -55,
#  -82,
#  -49,
#  -73,
#  -72,
#  -50,
#  -9,
#  -8,
#  -49,
#  -23,
#  -66,
#  -74,
#  -34,
#  -49,
#  -32,
#  -67,
#  -88,
#  -50,
#  -4,
#  -9,
#  -5,
#  -89,
#  -32,
#  -16,
#  -88,
#  -55,
#  -75,
#  -55,
#  -41,
#  -80,
#  -79,
#  -5,
#  -48,
#  -18,
# ...

# %%
duze = []
srednie = []
male = []

for each in liczby:
    if each >= 50:
        duze.append(each)
    elif each>= 0:
        srednie.append(each)
    else:
        male.append(each)

# %%
srednie
# Out:
# [10,
#  29,
#  7,
#  16,
#  21,
#  10,
#  46,
#  21,
#  17,
#  39,
#  42,
#  24,
#  1,
#  30,
#  21,
#  11,
#  42,
#  41,
#  34,
#  1,
#  13,
#  17,
#  9,
#  42,
#  36,
#  18,
#  1,
#  27,
#  5,
#  21,
#  19,
#  12,
#  22,
#  6,
#  10,
#  28,
#  27,
#  12,
#  15,
#  23,
#  47,
#  25,
#  46,
#  18,
#  26,
#  46,
#  6,
#  29,
#  30,
#  45,
#  2,
#  48,
#  19,
#  32,
#  13,
#  37,
#  24,
#  8,
#  33,
#  42,
#  21,
#  44,
#  33,
#  35,
#  41,
#  37,
#  3,
#  15,
#  41,
#  14,
#  31,
#  6,
#  16,
#  20,
#  27,
#  32,
#  33,
#  1,
#  28,
#  24,
#  1,
#  10,
#  24,
#  37,
#  46,
#  23,
#  8,
#  22,
#  11,
#  4,
#  9,
#  27,
#  29,
#  23,
#  5,
#  25,
#  34,
#  7,
#  39,
#  4,
#  30,
#  6,
#  24,
#  4,
#  5,
#  3,
#  27,
#  33,
#  41,
#  23,
#  30,
#  27,
#  41,
#  23,
#  26,
#  46,
#  1,
#  11,
#  46,
#  38,
#  49,
#  11,
#  8,
#  31,
#  8,
#  28,
#  43,
#  38,
#  8,
#  24,
#  3,
#  31,
#  31,
#  4,
#  33,
#  35,
#  16,
#  47,
#  40,
#  8,
#  17,
#  4,
#  28,
#  29,
#  44,
#  18,
#  14,
# ...

# %%
{NAZWA_PLIKU: {'typ': '.jpg', 'rozmiar' : '2.05'}}

# %%
fdict = {}

# %%
os.listdir('files')
# Out:
# ['(2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making.pdf',
#  '.DS_Store',
#  '.html',
#  '10.1523@jneurosci.2220-04.2004.pdf',
#  '100px-Coat_of_arms_of_Norway.svg.png',
#  '100px-Europe_orthographic_Caucasus_Urals_boundary_%28with_borders%29.svg.png',
#  '100px-Flag_of_La_Francophonie.svg.png',
#  '100px-Nordiske-flag.jpg',
#  '1042px-Summer_evening_at_Lovatnet%2C_Stryn%2C_Norway%2C_2013_June_-_3.jpg',
#  '11px-Decrease_Positive.svg.png',
#  '11px-Increase2.svg.png',
#  '11px-Increase_Negative.svg.png',
#  '11px-Loudspeaker.svg.png',
#  '12-brettspill-for-hele-familien-1.13974726.html',
#  '120px-08-08-01_Fl%C3%B8yen_utsikt.jpg',
#  '120px-Akureyri_rainbow.jpg',
#  '120px-Carte_du_Conseil_de_l%27Europe.png',
#  '120px-Hafnarfj%C3%B6r%C3%B0urHarbourView.JPG',
#  '120px-Hamraborgin_%C3%AD_K%C3%B3pavogi.JPG',
#  '120px-Lotnicza_panorama_Warszawy.jpg',
#  '120px-Neighborhood_of_Oslo_arial.jpg',
# ...

# %%
#fdict['NAZWA_PLIKU'] = 

for each in

# %%
spis = list(spis = os.listdir('files'))

# %%
spis
# Out:
# ['(2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making.pdf',
#  '.DS_Store',
#  '.html',
#  '10.1523@jneurosci.2220-04.2004.pdf',
#  '100px-Coat_of_arms_of_Norway.svg.png',
#  '100px-Europe_orthographic_Caucasus_Urals_boundary_%28with_borders%29.svg.png',
#  '100px-Flag_of_La_Francophonie.svg.png',
#  '100px-Nordiske-flag.jpg',
#  '1042px-Summer_evening_at_Lovatnet%2C_Stryn%2C_Norway%2C_2013_June_-_3.jpg',
#  '11px-Decrease_Positive.svg.png',
#  '11px-Increase2.svg.png',
#  '11px-Increase_Negative.svg.png',
#  '11px-Loudspeaker.svg.png',
#  '12-brettspill-for-hele-familien-1.13974726.html',
#  '120px-08-08-01_Fl%C3%B8yen_utsikt.jpg',
#  '120px-Akureyri_rainbow.jpg',
#  '120px-Carte_du_Conseil_de_l%27Europe.png',
#  '120px-Hafnarfj%C3%B6r%C3%B0urHarbourView.JPG',
#  '120px-Hamraborgin_%C3%AD_K%C3%B3pavogi.JPG',
#  '120px-Lotnicza_panorama_Warszawy.jpg',
#  '120px-Neighborhood_of_Oslo_arial.jpg',
# ...

# %%
for each_file in os.listdir('files'): 
    print(each_file)
# Out:
# (2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making.pdf
# .DS_Store
# .html
# 10.1523@jneurosci.2220-04.2004.pdf
# 100px-Coat_of_arms_of_Norway.svg.png
# 100px-Europe_orthographic_Caucasus_Urals_boundary_%28with_borders%29.svg.png
# 100px-Flag_of_La_Francophonie.svg.png
# 100px-Nordiske-flag.jpg
# 1042px-Summer_evening_at_Lovatnet%2C_Stryn%2C_Norway%2C_2013_June_-_3.jpg
# 11px-Decrease_Positive.svg.png
# 11px-Increase2.svg.png
# 11px-Increase_Negative.svg.png
# 11px-Loudspeaker.svg.png
# 12-brettspill-for-hele-familien-1.13974726.html
# 120px-08-08-01_Fl%C3%B8yen_utsikt.jpg
# 120px-Akureyri_rainbow.jpg
# 120px-Carte_du_Conseil_de_l%27Europe.png
# 120px-Hafnarfj%C3%B6r%C3%B0urHarbourView.JPG
# 120px-Hamraborgin_%C3%AD_K%C3%B3pavogi.JPG
# 120px-Lotnicza_panorama_Warszawy.jpg
# 120px-Neighborhood_of_Oslo_arial.jpg
# 120px-Orion_Business_Tower_-_poziom.jpg
# 120px-Overview_of_Trondheim_2008_03.jpg
# ...

# %%
for each_file in os.listdir('files'): 
    fdict[each_file] = dict()
    
    #może być też: fdict[each_file] = {}

# %%
fdict
# Out:
# {'(2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making.pdf': {},
#  '.DS_Store': {},
#  '.html': {},
#  '10.1523@jneurosci.2220-04.2004.pdf': {},
#  '100px-Coat_of_arms_of_Norway.svg.png': {},
#  '100px-Europe_orthographic_Caucasus_Urals_boundary_%28with_borders%29.svg.png': {},
#  '100px-Flag_of_La_Francophonie.svg.png': {},
#  '100px-Nordiske-flag.jpg': {},
#  '1042px-Summer_evening_at_Lovatnet%2C_Stryn%2C_Norway%2C_2013_June_-_3.jpg': {},
#  '11px-Decrease_Positive.svg.png': {},
#  '11px-Increase2.svg.png': {},
#  '11px-Increase_Negative.svg.png': {},
#  '11px-Loudspeaker.svg.png': {},
#  '12-brettspill-for-hele-familien-1.13974726.html': {},
#  '120px-08-08-01_Fl%C3%B8yen_utsikt.jpg': {},
#  '120px-Akureyri_rainbow.jpg': {},
#  '120px-Carte_du_Conseil_de_l%27Europe.png': {},
#  '120px-Hafnarfj%C3%B6r%C3%B0urHarbourView.JPG': {},
#  '120px-Hamraborgin_%C3%AD_K%C3%B3pavogi.JPG': {},
# ...

# %%
os.listdir('files')[0]
# Out:
# '(2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making.pdf'

# %%
os.listdir('files')[0].split('.') #zwraca listę (czyli edytowalna)
# Out:
# ['(2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making',
#  'pdf']

# %%
op.splitext(os.listdir('files')[0]) # zwraca touple, czyli nie zmienimy nic niechcący
# Out:
# ('(2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making',
#  '.pdf')

# %%
op.splitext(os.listdir('files')[0])[1]
# Out:
# '.pdf'

# %%
#można lepiej, sprawdzając typ pliku

# %%
op.splitext(each_file)[-1]
# Out:
# '.html'

# %%
for each_file in os.listdir('files'): 
    fdict[each_file] = dict()
    fdict[each_file]['typ'] = op.splitext(each_file)[-1]
    #może być też: fdict[each_file] = {}

# %%
fdict
# Out:
# {'(2014) Neural Oscillations and Synchronization Differentially Support Evidence Accumulation in Perceptual and Value-Based Decision Making.pdf': {'typ': '.pdf'},
#  '.DS_Store': {'typ': ''},
#  '.html': {'typ': ''},
#  '10.1523@jneurosci.2220-04.2004.pdf': {'typ': '.pdf'},
#  '100px-Coat_of_arms_of_Norway.svg.png': {'typ': '.png'},
#  '100px-Europe_orthographic_Caucasus_Urals_boundary_%28with_borders%29.svg.png': {'typ': '.png'},
#  '100px-Flag_of_La_Francophonie.svg.png': {'typ': '.png'},
#  '100px-Nordiske-flag.jpg': {'typ': '.jpg'},
#  '1042px-Summer_evening_at_Lovatnet%2C_Stryn%2C_Norway%2C_2013_June_-_3.jpg': {'typ': '.jpg'},
#  '11px-Decrease_Positive.svg.png': {'typ': '.png'},
#  '11px-Increase2.svg.png': {'typ': '.png'},
#  '11px-Increase_Negative.svg.png': {'typ': '.png'},
#  '11px-Loudspeaker.svg.png': {'typ': '.png'},
#  '12-brettspill-for-hele-familien-1.13974726.html': {'typ': '.html'},
#  '120px-08-08-01_Fl%C3%B8yen_utsikt.jpg': {'typ': '.jpg'},
# ...

# %%
fdict['266px-South_of_Iceland%2C_off_the_Ring_Road.jpg']
# Out:
# {'typ': '.jpg'}

# %%
os.path.getsize('C:\\Users\\apiotro8\\files\\s01_e08.zip')
# Out:
# 15183210

# %%
filepath
# Out:
# 'C:\\Users\\apiotro8\\files\\s01_e08.zip'

# %%
sciezka
# Out:
# 'C:\\Users\\apiotro8\\files'

# %%
each_file
# Out:
# '_vietnams-lady-gaga_-holdt-igjen-av-styresmakter-etter-europa-turne-1.13982539.html'

# %%
op.join(sciezka, each_file)
# Out:
# 'C:\\Users\\apiotro8\\files\\_vietnams-lady-gaga_-holdt-igjen-av-styresmakter-etter-europa-turne-1.13982539.html'

# %%
for each_file in os.listdir('files'): 
    fdict[each_file] = dict()
    cur_file = op.join('C:\\Users\\apiotro8\\files\\files', each_file)
    fdict[each_file]['typ'] = op.splitext(cur_file)[-1]
    fdict[each_file]['rozmiar'] = op.getsize(cur_file)/1000

# %%
nowyslownik = dict()

# %%
for each_file in os.listdir('files'): 
    print(each)
# Out:
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# 97
# ...

# %%
for each in os.listdir('files'): 
    print(each[:15])
# Out:
# (2014) Neural O
# .DS_Store
# .html
# 10.1523@jneuros
# 100px-Coat_of_a
# 100px-Europe_or
# 100px-Flag_of_L
# 100px-Nordiske-
# 1042px-Summer_e
# 11px-Decrease_P
# 11px-Increase2.
# 11px-Increase_N
# 11px-Loudspeake
# 12-brettspill-f
# 120px-08-08-01_
# 120px-Akureyri_
# 120px-Carte_du_
# 120px-Hafnarfj%
# 120px-Hamraborg
# 120px-Lotnicza_
# 120px-Neighborh
# 120px-Orion_Bus
# 120px-Overview_
# 120px-Prezydent
# 120px-Reykjavik
# 120px-Stavanger
# 120px-Sukiennic
# 120px-Wroc%C5%8
# 125px-Flag_of_I
# 125px-Flag_of_N
# 125px-Flag_of_P
# 125px-Morawieck
# 131px-Laxness_p
# 135px-Thorfinn_
# 140px-Manor_of_
# 150px-En_brud_f
# 150px-Gjermundb
# 150px-Joseph_Co
# 150px-Marie_Cur
# 150px-Polish_So
# 160px-Helena_Ru
# 168px-Pasteura_
# 16px-Flag_of_Sw
# 16px-Folder_Hex
# 16px-Gnome-glob
# 16px-Openstreet
# 16px-Searchtool
# 170px-7TP-2.jpg
# 170px-Arthur_Ru
# 170px-Ayuntamie
# 170px-Bagel-Pla
# 170px-Battle_of
# 170px-Casimir_t
# 170px-Darstellu
# 170px-Edvard_Gr
# 170px-FeleHel_%
# ...

# %%
# klasyczny sposób
nazwy_plikow = list()
for each in os.listdir('files'): 
    nazwy_plikow.append(each[:15])

# %%
# w 1 linijce - list comprehension
nazwy_plikow2 = [each[:15] for each in os.listdir('files')]

# %%
rozmiary = list()
for each in os.listdir('files'): 
    
    fpath = 'C:\\Users\\apiotro8\\files\\files'
    cur_file = op.join(fpath, each)
    rozmiary.append(np.round(op.getsize(cur_file)/1000000, 3))
    #fdict[each_file]['typ'] = op.splitext(cur_file)[-1]
    #fdict[each_file]['rozmiar'] = op.getsize(cur_file)/1000

# %%
for each_file in os.listdir('files'): 
    nowyslownikslownik[each_file] = dict()
    
    
    nowyslownik['fname'] = each_file[1:15]
    nowyslownik['size_mb'] = op.getsize(cur_file, decimals = 2)/1000
    nowyslownik['type'] = op.splitext(cur_file)[-1]
